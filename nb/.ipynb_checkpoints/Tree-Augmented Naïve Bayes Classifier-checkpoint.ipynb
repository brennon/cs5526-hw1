# %% [markdown]
# # Tree-Augmented Naïve Bayes Classifier
# This notebook demonstrates the implementation of a Tree-Augmented Naïve Bayes Classifier for the mushroom dataset available from the UCI Machine Learning Repository. This implementation uses Python and the `libpgm` library for working with probabilistic graphical models.

# %% [markdown]
# ## Define nodes and edges
#
# Much like in the simple Naïve Bayes Classifier, we first need to build a list of nodes and edges for the graph given the data in the data file. We use the same `create_nodes_from_header()` to create the nodes, but we begin with no edges defined.

# %%
import csv

def create_nodes_from_header(filename):
    """
        Returns a list of node labels for an NBC from the CSV file at *filename*.
        Assumes that the first row of this file contains unquoted node labels.
    """
    csv_file = open(filename, 'r')
    reader = csv.reader(csv_file)
    nodes = reader.next()
    csv_file.close()
    return nodes

data_file_path = 'mushroom.csv'

nodes = create_nodes_from_header(data_file_path)
edges = []

from pprint import pprint

print('Nodes:')
pprint(nodes)

print('Edges:')
pprint(edges)
# Out:
# Nodes:
# ['poisonous',
#  'cap_shape',
#  'cap_surface',
#  'cap_color',
#  'bruises',
#  'odor',
#  'gill_attachment',
#  'gill_spacing',
#  'gill_size',
#  'gill_color',
#  'stalk_shape',
#  'stalk_root',
#  'stalk_surface_above_ring',
#  'stalk_surface_below_ring',
#  'stalk_color_above_ring',
#  'stalk_color_below_ring',
#  'veil_type',
#  'veil_color',
#  'ring_number',
#  'ring_type',
#  'spore_print_color',
#  'population',
#  'habitat']
# Edges:
# []

# %% [markdown]
# ## Parse observations
#
# Again, we parse observations from the data file with `create_observations_from_csv()`.

# %%
def create_observations_from_csv(filename, fieldnames):
    """
        Returns a dictionary of observations from data in the CSV file at *filename*.
        Assumes that the first row of this file contains node labels.
    """
    observations = []
    csv_file = open(filename)
    reader = csv.DictReader(csv_file, fieldnames=fieldnames)
    reader.next()
    for row in reader:
        observation = dict()
        for node in nodes:
            observation[node] = row[node]
        observations.append(observation)
    return observations

observations = create_observations_from_csv(data_file_path, nodes)
pprint(observations[0])
# Out:
# {'bruises': 't',
#  'cap_color': 'n',
#  'cap_shape': 'x',
#  'cap_surface': 's',
#  'gill_attachment': 'f',
#  'gill_color': 'k',
#  'gill_size': 'n',
#  'gill_spacing': 'c',
#  'habitat': 'u',
#  'odor': 'p',
#  'poisonous': 'p',
#  'population': 's',
#  'ring_number': 'o',
#  'ring_type': 'p',
#  'spore_print_color': 'k',
#  'stalk_color_above_ring': 'w',
#  'stalk_color_below_ring': 'w',
#  'stalk_root': 'e',
#  'stalk_shape': 'e',
#  'stalk_surface_above_ring': 's',
#  'stalk_surface_below_ring': 's',
#  'veil_color': 'w',
#  'veil_type': 'p'}

# %% [markdown]
# ## Building the tree structure

# %% [markdown]
# ### Calculating mutual information
#
# We derive the tree structure for the classifier based on mutual information between all pairs of feature nodes. For efficiency, we define `save_mutual_information()` and `load_mutual_information()`. `save_mutual_information()` calculates these measures and persists them to a JSON file, and `load_mutual_information()` loads this data.

# %%
import json

def save_mutual_information(nodes, observations, Vdata):
    edges_for_tree = []
    nodes_for_tree = nodes[:]

    for i in range(len(nodes_for_tree)):
        for j in range(i + 1, len(nodes_for_tree)):
            node_a = nodes_for_tree[i]
            node_b = nodes_for_tree[j]

            mi = manual_mutual_information(node_a, node_b, observations, bn.Vdata)
            edge = (node_a, node_b, mi)
            edges_for_tree.append(edge)

    dump_file = open('tanbc-mi.json', 'w')
    json.dump(edges_for_tree, dump_file)
    dump_file.close()

def load_mutual_information():
    dump_file = open('tanbc-mi.json', 'r')
    return json.load(dump_file)

# save_mutual_information(nodes[1:], observations, bn.Vdata)

edges_with_weights = load_mutual_information()
pprint(edges_with_weights)
# Out:
# [[u'cap_shape', u'cap_surface', 0.0499234078522392],
#  [u'cap_shape', u'cap_color', 0.11121103749010143],
#  [u'cap_shape', u'bruises', 0.05594462375801892],
#  [u'cap_shape', u'odor', 0.18668492726962985],
#  [u'cap_shape', u'gill_attachment', 0.012064269129158747],
#  [u'cap_shape', u'gill_spacing', 0.004653088656394367],
#  [u'cap_shape', u'gill_size', 0.08776566216863622],
#  [u'cap_shape', u'gill_color', 0.19199525812992593],
#  [u'cap_shape', u'stalk_shape', 0.0841071918111748],
#  [u'cap_shape', u'stalk_root', 0.30013018279520004],
#  [u'cap_shape', u'stalk_surface_above_ring', 0.03253373452407502],
#  [u'cap_shape', u'stalk_surface_below_ring', 0.0325640758122396],
#  [u'cap_shape', u'stalk_color_above_ring', 0.09622248720680952],
#  [u'cap_shape', u'stalk_color_below_ring', 0.09154436342299871],
#  [u'cap_shape', u'veil_type', 0.0],
#  [u'cap_shape', u'veil_color', 0.015187513179505566],
#  [u'cap_shape', u'ring_number', 0.041651695971857174],
#  [u'cap_shape', u'ring_type', 0.14041490832090545],
#  [u'cap_shape', u'spore_print_color', 0.22657603919263078],
#  [u'cap_shape', u'population', 0.18067909662077222],
#  [u'cap_shape', u'habitat', 0.17496097082657988],
#  [u'cap_surface', u'cap_color', 0.11066848123053499],
#  [u'cap_surface', u'bruises', 0.013183428894660912],
#  [u'cap_surface', u'odor', 0.1666394609318564],
#  [u'cap_surface', u'gill_attachment', 0.032290757967868934],
#  [u'cap_surface', u'gill_spacing', 0.10644160341276802],
#  [u'cap_surface', u'gill_size', 0.060719614543614325],
#  [u'cap_surface', u'gill_color', 0.1916316851403271],
#  [u'cap_surface', u'stalk_shape', 0.004627231050074403],
#  [u'cap_surface', u'stalk_root', 0.25805038433650274],
#  [u'cap_surface', u'stalk_surface_above_ring', 0.05661135525867861],
#  [u'cap_surface', u'stalk_surface_below_ring', 0.06818427830162262],
#  [u'cap_surface', u'stalk_color_above_ring', 0.17573534109154398],
#  [u'cap_surface', u'stalk_color_below_ring', 0.18283083986361395],
#  [u'cap_surface', u'veil_type', 0.0],
#  [u'cap_surface', u'veil_color', 0.04160719428599182],
#  [u'cap_surface', u'ring_number', 0.014771000639864262],
#  [u'cap_surface', u'ring_type', 0.1443791106380365],
#  [u'cap_surface', u'spore_print_color', 0.13352488293719864],
#  [u'cap_surface', u'population', 0.19542633910258153],
#  [u'cap_surface', u'habitat', 0.1612774606586819],
#  [u'cap_color', u'bruises', 0.04043855641597459],
#  [u'cap_color', u'odor', 0.5698963476759185],
#  [u'cap_color', u'gill_attachment', 0.043493566383935485],
#  [u'cap_color', u'gill_spacing', 0.12326051272225014],
#  [u'cap_color', u'gill_size', 0.18076333535627895],
#  [u'cap_color', u'gill_color', 0.5465946691083967],
#  [u'cap_color', u'stalk_shape', 0.30613806948787464],
#  [u'cap_color', u'stalk_root', 0.46611342461281435],
#  [u'cap_color', u'stalk_surface_above_ring', 0.1591871468958389],
#  [u'cap_color', u'stalk_surface_below_ring', 0.22053761510019623],
#  [u'cap_color', u'stalk_color_above_ring', 0.3939004541936122],
#  [u'cap_color', u'stalk_color_below_ring', 0.3967290497264319],
#  [u'cap_color', u'veil_type', 0.0],
#  [u'cap_color', u'veil_color', 0.04718129796406426],
#  [u'cap_color', u'ring_number', 0.08004321646811885],
#  [u'cap_color', u'ring_type', 0.42908468370996317],
#  [u'cap_color', u'spore_print_color', 0.47938965720868826],
#  [u'cap_color', u'population', 0.3430677021512927],
#  [u'cap_color', u'habitat', 0.46958696103187253],
#  [u'bruises', u'odor', 0.40169429661231604],
#  [u'bruises', u'gill_attachment', 0.020380826233787234],
#  [u'bruises', u'gill_spacing', 0.0772271582606359],
#  [u'bruises', u'gill_size', 0.10801541244222916],
#  [u'bruises', u'gill_color', 0.3774241140562746],
#  [u'bruises', u'stalk_shape', 0.007158400859440292],
#  [u'bruises', u'stalk_root', 0.271000041008353],
#  [u'bruises', u'stalk_surface_above_ring', 0.3146987485952055],
#  [u'bruises', u'stalk_surface_below_ring', 0.30502122734220033],
#  [u'bruises', u'stalk_color_above_ring', 0.22551066534226835],
#  [u'bruises', u'stalk_color_below_ring', 0.23482905108506785],
#  [u'bruises', u'veil_type', 0.0],
#  [u'bruises', u'veil_color', 0.019394030135379912],
#  [u'bruises', u'ring_number', 0.00479161110250005],
#  [u'bruises', u'ring_type', 0.5051237054824236],
#  [u'bruises', u'spore_print_color', 0.3000490267950862],
#  [u'bruises', u'population', 0.07734300118443467],
#  [u'bruises', u'habitat', 0.24688416874306837],
#  [u'odor', u'gill_attachment', 0.03629277683543007],
#  [u'odor', u'gill_spacing', 0.17058058741158183],
#  [u'odor', u'gill_size', 0.46198985506068185],
#  [u'odor', u'gill_color', 0.8674717237798779],
#  [u'odor', u'stalk_shape', 0.29798302936356763],
#  [u'odor', u'stalk_root', 0.8356069043202407],
#  [u'odor', u'stalk_surface_above_ring', 0.4302270866397128],
#  [u'odor', u'stalk_surface_below_ring', 0.5054727333907417],
#  [u'odor', u'stalk_color_above_ring', 0.5204519081207518],
#  [u'odor', u'stalk_color_below_ring', 0.5044138187058459],
#  [u'odor', u'veil_type', 0.0],
#  [u'odor', u'veil_color', 0.030209793653899284],
#  [u'odor', u'ring_number', 0.1349918890273552],
#  [u'odor', u'ring_type', 0.7560979059272684],
#  [u'odor', u'spore_print_color', 0.9520306069454362],
#  [u'odor', u'population', 0.4584813140103381],
#  [u'odor', u'habitat', 0.4982288349719173],
#  [u'gill_attachment', u'gill_spacing', 0.006663246351913503],
#  [u'gill_attachment', u'gill_size', 0.014015559342756993],
#  [u'gill_attachment', u'gill_color', 0.11444153761680306],
#  [u'gill_attachment', u'stalk_shape', 0.03188293891361054],
#  [u'gill_attachment', u'stalk_root', 0.0390427364897303],
#  [u'gill_attachment', u'stalk_surface_above_ring', 0.00856330028413515],
#  [u'gill_attachment', u'stalk_surface_below_ring', 0.01708964920005301],
#  [u'gill_attachment', u'stalk_color_above_ring', 0.1686975791467388],
#  [u'gill_attachment', u'stalk_color_below_ring', 0.1686975791467388],
#  [u'gill_attachment', u'veil_type', 0.0],
#  [u'gill_attachment', u'veil_color', 0.15047791142831657],
#  [u'gill_attachment', u'ring_number', 0.010128810466763916],
#  [u'gill_attachment', u'ring_type', 0.03217886852557359],
#  [u'gill_attachment', u'spore_print_color', 0.11424648194251394],
#  [u'gill_attachment', u'population', 0.05401761680248894],
#  [u'gill_attachment', u'habitat', 0.07361898517799427],
#  [u'gill_spacing', u'gill_size', 0.009084207210550466],
#  [u'gill_spacing', u'gill_color', 0.09698967850715165],
#  [u'gill_spacing', u'stalk_shape', 0.004810136301417311],
#  [u'gill_spacing', u'stalk_root', 0.18597943403914563],
#  [u'gill_spacing', u'stalk_surface_above_ring', 0.1015299110648533],
#  [u'gill_spacing', u'stalk_surface_below_ring', 0.09487397404249118],
#  [u'gill_spacing', u'stalk_color_above_ring', 0.15903838996409803],
#  [u'gill_spacing', u'stalk_color_below_ring', 0.14054933721265675],
#  [u'gill_spacing', u'veil_type', 0.0],
#  [u'gill_spacing', u'veil_color', 0.008644482351544006],
#  [u'gill_spacing', u'ring_number', 0.03350623357246903],
#  [u'gill_spacing', u'ring_type', 0.07535887374623655],
#  [u'gill_spacing', u'spore_print_color', 0.08680412069981681],
#  [u'gill_spacing', u'population', 0.28989645475625236],
#  [u'gill_spacing', u'habitat', 0.20505933877948118],
#  [u'gill_size', u'gill_color', 0.4906266877823653],
#  [u'gill_size', u'stalk_shape', 0.03427134925606763],
#  [u'gill_size', u'stalk_root', 0.29914224191712774],
#  [u'gill_size', u'stalk_surface_above_ring', 0.026651273163434252],
#  [u'gill_size', u'stalk_surface_below_ring', 0.018474185991219028],
#  [u'gill_size', u'stalk_color_above_ring', 0.14154984556494055],
#  [u'gill_size', u'stalk_color_below_ring', 0.12174283124303166],
#  [u'gill_size', u'veil_type', 0.0],
#  [u'gill_size', u'veil_color', 0.014431687707259905],
#  [u'gill_size', u'ring_number', 0.0438948463215682],
#  [u'gill_size', u'ring_type', 0.26072562157440693],
#  [u'gill_size', u'spore_print_color', 0.3290445179194227],
#  [u'gill_size', u'population', 0.22902948739239803],
#  [u'gill_size', u'habitat', 0.20030635876515684],
#  [u'gill_color', u'stalk_shape', 0.3631698487652846],
#  [u'gill_color', u'stalk_root', 0.8116967675108128],
#  [u'gill_color', u'stalk_surface_above_ring', 0.32428753667876864],
#  [u'gill_color', u'stalk_surface_below_ring', 0.3722806093968046],
#  [u'gill_color', u'stalk_color_above_ring', 0.5011619116850259],
#  [u'gill_color', u'stalk_color_below_ring', 0.4975951285789563],
#  [u'gill_color', u'veil_type', 0.0],
#  [u'gill_color', u'veil_color', 0.11452002870131224],
#  [u'gill_color', u'ring_number', 0.1627894062291479],
#  [u'gill_color', u'ring_type', 0.7777824795168892],
#  [u'gill_color', u'spore_print_color', 0.9502027811942771],
#  [u'gill_color', u'population', 0.5094186964445834],
#  [u'gill_color', u'habitat', 0.6431808544498088],
#  [u'stalk_shape', u'stalk_root', 0.13283005159882344],
#  [u'stalk_shape', u'stalk_surface_above_ring', 0.08335240132042088],
#  [u'stalk_shape', u'stalk_surface_below_ring', 0.11046646553222571],
#  [u'stalk_shape', u'stalk_color_above_ring', 0.26821650752983317],
#  [u'stalk_shape', u'stalk_color_below_ring', 0.2807426214606109],
#  [u'stalk_shape', u'veil_type', 0.0],
#  [u'stalk_shape', u'veil_color', 0.0303343769957354],
#  [u'stalk_shape', u'ring_number', 0.10094259969062866],
#  [u'stalk_shape', u'ring_type', 0.3387735750548718],
#  [u'stalk_shape', u'spore_print_color', 0.16590903719013417],
#  [u'stalk_shape', u'population', 0.18756592161345648],
#  [u'stalk_shape', u'habitat', 0.14460521252183645],
#  [u'stalk_root', u'stalk_surface_above_ring', 0.20559456667005332],
#  [u'stalk_root', u'stalk_surface_below_ring', 0.3243364583172071],
#  [u'stalk_root', u'stalk_color_above_ring', 0.44308301182378407],
#  [u'stalk_root', u'stalk_color_below_ring', 0.4451523162043623],
#  [u'stalk_root', u'veil_type', 0.0],
#  [u'stalk_root', u'veil_color', 0.045192042749212104],
#  [u'stalk_root', u'ring_number', 0.08614933191723004],
#  [u'stalk_root', u'ring_type', 0.6503578052664887],
#  [u'stalk_root', u'spore_print_color', 0.8743489309505821],
#  [u'stalk_root', u'population', 0.6944989177254752],
#  [u'stalk_root', u'habitat', 0.6812394987242057],
#  [u'stalk_surface_above_ring',
#   u'stalk_surface_below_ring',
#   0.4192402456433683],
#  [u'stalk_surface_above_ring', u'stalk_color_above_ring', 0.382935282037935],
#  [u'stalk_surface_above_ring', u'stalk_color_below_ring', 0.36757775986876345],
#  [u'stalk_surface_above_ring', u'veil_type', 0.0],
#  [u'stalk_surface_above_ring', u'veil_color', 0.024113122050560612],
#  [u'stalk_surface_above_ring', u'ring_number', 0.021501556016366503],
#  [u'stalk_surface_above_ring', u'ring_type', 0.4906940529804022],
#  [u'stalk_surface_above_ring', u'spore_print_color', 0.47724147601193806],
#  [u'stalk_surface_above_ring', u'population', 0.18767358725260164],
#  [u'stalk_surface_above_ring', u'habitat', 0.21398829374500988],
#  [u'stalk_surface_below_ring', u'stalk_color_above_ring', 0.4103545442850913],
#  [u'stalk_surface_below_ring', u'stalk_color_below_ring', 0.39529933008787094],
#  [u'stalk_surface_below_ring', u'veil_type', 0.0],
#  [u'stalk_surface_below_ring', u'veil_color', 0.022004685619622613],
#  [u'stalk_surface_below_ring', u'ring_number', 0.03186849060452468],
#  [u'stalk_surface_below_ring', u'ring_type', 0.5238062253127777],
#  [u'stalk_surface_below_ring', u'spore_print_color', 0.4877046813439696],
#  [u'stalk_surface_below_ring', u'population', 0.2050816157278735],
#  [u'stalk_surface_below_ring', u'habitat', 0.22056780711423435],
#  [u'stalk_color_above_ring', u'stalk_color_below_ring', 0.6535902003115729],
#  [u'stalk_color_above_ring', u'veil_type', 0.0],
#  [u'stalk_color_above_ring', u'veil_color', 0.17260461800334723],
#  [u'stalk_color_above_ring', u'ring_number', 0.1348574469007408],
#  [u'stalk_color_above_ring', u'ring_type', 0.593426721802351],
#  [u'stalk_color_above_ring', u'spore_print_color', 0.5460018651926414],
#  [u'stalk_color_above_ring', u'population', 0.4388239828475807],
#  [u'stalk_color_above_ring', u'habitat', 0.4435983927456124],
#  [u'stalk_color_below_ring', u'veil_type', 0.0],
#  [u'stalk_color_below_ring', u'veil_color', 0.1698917794980164],
#  [u'stalk_color_below_ring', u'ring_number', 0.13613207533830576],
#  [u'stalk_color_below_ring', u'ring_type', 0.572200962211037],
#  [u'stalk_color_below_ring', u'spore_print_color', 0.5359517464859771],
#  [u'stalk_color_below_ring', u'population', 0.4412334098945206],
#  [u'stalk_color_below_ring', u'habitat', 0.4393551462484006],
#  [u'veil_type', u'veil_color', 0.0],
#  [u'veil_type', u'ring_number', 0.0],
#  [u'veil_type', u'ring_type', 0.0],
#  [u'veil_type', u'spore_print_color', 0.0],
#  [u'veil_type', u'population', 0.0],
#  [u'veil_type', u'habitat', 0.0],
#  [u'veil_color', u'ring_number', 0.0029331473887824],
#  [u'veil_color', u'ring_type', 0.02635729479493467],
#  [u'veil_color', u'spore_print_color', 0.12301632332336457],
#  [u'veil_color', u'population', 0.049819073753387635],
#  [u'veil_color', u'habitat', 0.08515217924079221],
#  [u'ring_number', u'ring_type', 0.06330064089745319],
#  [u'ring_number', u'spore_print_color', 0.16509160956687377],
#  [u'ring_number', u'population', 0.135579242562204],
#  [u'ring_number', u'habitat', 0.16389108094740001],
#  [u'ring_type', u'spore_print_color', 0.8151257653641972],
#  [u'ring_type', u'population', 0.3669970926926557],
#  [u'ring_type', u'habitat', 0.3033777975633837],
#  [u'spore_print_color', u'population', 0.3405182983377094],
#  [u'spore_print_color', u'habitat', 0.435382237029595],
#  [u'population', u'habitat', 0.645572769311101]]

# %% [markdown]
# ### Determining tree structure
#
# Given the mutual information, we calculate the tree structure amongst the feature nodes using the Chow-Liu algorithm. This is accomplished through three functions: `edges_for_maximum_spanning_tree()`, `cheapest_non_tree_edge()`, and `assign_edge_directions()`. `edges_for_maximum_spanning_tree()` uses `cheapest_non_tree_edge()` to iteratively add edges to the tree that provide the most mutual information. Once a minimum spanning tree (using *negative* edge weights) has been constructed, the directions of all edges are determined using `assign_edge_directions()`.

# %%
import random

def edges_for_maximum_spanning_tree(nodes, all_edges):
    added_nodes = []
    remaining_nodes = nodes[:]
    available_edges = all_edges[:]
    selected_edges = []

    # Select a random starting node.
    start_node = random.choice(remaining_nodes)
    remaining_nodes.remove(start_node)
    added_nodes.append(start_node)

    # Make all edge costs the negative of their original cost.
    available_edges = [[edge[0], edge[1], -edge[2]] for edge in available_edges]

    while len(remaining_nodes):
        next_edge = cheapest_tree_non_tree_edge(added_nodes, remaining_nodes, available_edges)
        selected_edges.append(next_edge)
        available_edges.remove(next_edge)

        if next_edge[0] in remaining_nodes:
            remaining_nodes.remove(next_edge[0])
            added_nodes.append(next_edge[0])

        if next_edge[1] in remaining_nodes:
            remaining_nodes.remove(next_edge[1])
            added_nodes.append(next_edge[1])

    directed_edges = assign_edge_directions(added_nodes, selected_edges)

    return directed_edges

def cheapest_tree_non_tree_edge(nodes_in_tree, nodes_not_in_tree, available_edges):
    valid_edges = []
    for edge in available_edges:
        if (edge[0] in nodes_in_tree and edge[1] in nodes_not_in_tree) or (edge[1] in nodes_in_tree and edge[0] in nodes_not_in_tree):
            valid_edges.append(edge)
    edge_costs = [edge[2] for edge in valid_edges]

    cheapest_edge = None
    cheapest_cost = float("inf")
    for edge in valid_edges:
        if edge[2] < cheapest_cost:
            cheapest_edge = edge
            cheapest_cost = edge[2]

    return cheapest_edge

def assign_edge_directions(nodes, edges):
    all_edges = edges[:]
    
    visited_nodes = []
    make_parent = []

    # Select random root node.
    root = random.choice(nodes)
    make_parent.append(root)

    # Visit each node.
    while len(make_parent) > 0:

        # Get next node to make a parent.
        visiting = make_parent[0]

        # Remove it from the make_parent list.
        make_parent = make_parent[1:]

        # Add it node to the visited list.
        visited_nodes.append(visiting)

        # Check each edge in all_edges.
        for i in range(len(all_edges)):

            # If current edge terminus is this node and if current edge start is not 
            # in the visited list, swap start and terminus.
            if all_edges[i][1] == visiting and all_edges[i][0] not in visited_nodes:
                all_edges[i][0], all_edges[i][1] = all_edges[i][1], all_edges[i][0]

            # If the terminus isn't in the list of visited nodes, add it to the list.
            if all_edges[i][0] == visiting and all_edges[i][1] not in make_parent:
                make_parent.append(all_edges[i][1])

    return all_edges

final_edges = edges_for_maximum_spanning_tree(nodes[1:], edges_with_weights)
pprint(final_edges)
# Out:
# [[u'stalk_root', u'population', -0.6944989177254752],
#  [u'stalk_root', u'spore_print_color', -0.8743489309505821],
#  [u'spore_print_color', u'odor', -0.9520306069454362],
#  [u'spore_print_color', u'gill_color', -0.9502027811942771],
#  [u'spore_print_color', u'ring_type', -0.8151257653641972],
#  [u'habitat', u'stalk_root', -0.6812394987242057],
#  [u'ring_type', u'stalk_color_above_ring', -0.593426721802351],
#  [u'stalk_color_above_ring', u'stalk_color_below_ring', -0.6535902003115729],
#  [u'odor', u'cap_color', -0.5698963476759185],
#  [u'ring_type', u'stalk_surface_below_ring', -0.5238062253127777],
#  [u'ring_type', u'bruises', -0.5051237054824236],
#  [u'ring_type', u'stalk_surface_above_ring', -0.4906940529804022],
#  [u'gill_color', u'gill_size', -0.4906266877823653],
#  [u'gill_color', u'stalk_shape', -0.3631698487652846],
#  [u'stalk_root', u'cap_shape', -0.30013018279520004],
#  [u'population', u'gill_spacing', -0.28989645475625236],
#  [u'stalk_root', u'cap_surface', -0.25805038433650274],
#  [u'stalk_color_above_ring', u'veil_color', -0.17260461800334723],
#  [u'stalk_color_above_ring', u'gill_attachment', -0.1686975791467388],
#  [u'spore_print_color', u'ring_number', -0.16509160956687377],
#  [u'cap_shape', u'veil_type', -0.0]]

# %% [markdown]
# ### Finalizing the graph
#
# We now remove the edge weights and add an edge from the class node to each feature node. This completes the tree-augmented naïve Bayes network structure.

# %%
from libpgm.graphskeleton import GraphSkeleton

def remove_weights_from_edges(edges):
    removing_weights = edges[:]
    return [[edge[0], edge[1]] for edge in removing_weights]

def create_graph_skeleton(nodes, edges):
    graphSkeleton = GraphSkeleton()
    graphSkeleton.V = nodes
    graphSkeleton.E = edges
    graphSkeleton.toporder()
    return graphSkeleton

# Strip unnecessary weights from edges.
edges = remove_weights_from_edges(final_edges)

# Add edges from class node to all other nodes.
for i in range(1, len(nodes)):
    edges.append([nodes[0], nodes[i]])

# Create a new GraphSkeleton with our tree-augmented network
graphSkeleton = create_graph_skeleton(nodes, edges)

# %% [markdown]
# ## Completing the classifier
#
# We now proceed as in the previous simple naïve Bayes classifier and complete with a 10-fold cross validation run. The validation run (see the source in the [Github](https://github.com/brennon/cs5526-hw1) repository) gives the following output:
#
# ```
# Performing 10-fold cross validation.
# 	Running iteration 1.
# 		Accuracy: 1.0
# 	Running iteration 2.
# 		Accuracy: 1.0
# 	Running iteration 3.
# 		Accuracy: 1.0
# 	Running iteration 4.
# 		Accuracy: 1.0
# 	Running iteration 5.
# 		Accuracy: 1.0
# 	Running iteration 6.
# 		Accuracy: 1.0
# 	Running iteration 7.
# 		Accuracy: 0.997536945813
# 	Running iteration 8.
# 		Accuracy: 1.0
# 	Running iteration 9.
# 		Accuracy: 1.0
# 	Running iteration 10.
# 		Accuracy: 0.997536945813
# 	Weighted accuracy: 0.999507389163
# ```
